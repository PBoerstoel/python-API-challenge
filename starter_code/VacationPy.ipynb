# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       gangtok  27.3333   88.6167     19.81        98         100
# 1        1  longyearbyen  78.2186   15.6401      6.91        87           0
# 2        2    brokopondo   4.7500  -55.1667     25.93        84          91
# 3        3     adamstown -25.0660 -130.1015     22.23        85          95
# 4        4  punta arenas -53.1500  -70.9167      1.27        94          45
#
#    Wind Speed Country        Date
# 0        1.01      IN  1691550650
# 1        1.54      SJ  1691550650
# 2        3.46      SR  1691550642
# 3       15.43      PN  1691550650
# 4        4.01      CL  1691550025

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map = city_data_df.hvplot.points("Lng","Lat", size = "Humidity", geo = True, tiles = "OSM")

# Display the map
city_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_df = city_data_df.loc[(city_data_df['Max Temp'] >= 22) & (city_data_df['Max Temp'] <= 26) & 
                           (city_data_df['Humidity'] <= 90) & (city_data_df['Wind Speed'] <= 10)
                           & (city_data_df['Cloudiness'] <= 50)]

# Drop any rows with null values
ideal_df = ideal_df.dropna()

# Display sample data
ideal_df
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 9          9                      tual  -5.6667  132.7500     25.57        81
# 17        17  petropavlovsk-kamchatsky  53.0452  158.6483     22.33        46
# 29        29                    avarua -21.2078 -159.7750     24.03        60
# 55        55                  itaituba  -4.2761  -55.9836     25.40        63
# 87        87               mozarlandia -14.7447  -50.5706     25.56        28
# 90        90                  hamilton  39.1834  -84.5333     23.18        80
# 117      117                   karasuk  53.7377   78.0403     23.79        44
# 127      127                  mytilene  39.1100   26.5547     23.90        64
# 133      133                  st. paul  44.9444  -93.0933     24.52        64
# 145      145                     ouani -12.1322   44.4258     24.21        77
# 146      146                 al muwayh  22.4333   41.7583     25.17        18
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[['City', 'Lat','Lng','Humidity','Country']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                          City      Lat       Lng  Humidity Country Hotel Name
# 9                        tual  -5.6667  132.7500        81      ID
# 17   petropavlovsk-kamchatsky  53.0452  158.6483        46      RU
# 29                     avarua -21.2078 -159.7750        60      CK
# 55                   itaituba  -4.2761  -55.9836        63      BR
# 87                mozarlandia -14.7447  -50.5706        28      BR
# 90                   hamilton  39.1834  -84.5333        80      US
# 117                   karasuk  53.7377   78.0403        44      RU
# 127                  mytilene  39.1100   26.5547        64      GR
# 133                  st. paul  44.9444  -93.0933        64      US
# 145                     ouani -12.1322   44.4258        77      KM
# 146                 al muwayh  22.4333   41.7583        18      SA
# 156             orchard homes  46.8633 -114.0484        54      US
# 166               nova sintra  14.8667  -24.7167        73      CV
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel", #I used accommodation.hotel instead of accommodation to get specifically hotels
    "apiKey": geoapify_key, #my key
    "units":"metric" #in metric units
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}" #make a circle of radius 10000 m from the city
    params["bias"] = f"proximity:{longitude},{latitude}" #bias towards closest
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tual - nearest hotel: Suita
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# avarua - nearest hotel: Paradise Inn
# itaituba - nearest hotel: TG Hotel
# mozarlandia - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# karasuk - nearest hotel: Фаворит
# mytilene - nearest hotel: ΛΑ ΜΙΡΑΖ
# st. paul - nearest hotel: Crowne Plaza
# ouani - nearest hotel: Al Amal
# al muwayh - nearest hotel: فندق ومطعم الموية
# orchard homes - nearest hotel: Broadway Inn
# nova sintra - nearest hotel: Residência Ka Dencho
# klyuchi - nearest hotel: No hotel found
# afif - nearest hotel: Samaya Royal Afif
# danville - nearest hotel: Holiday Inn Express Danville
# emerald - nearest hotel: Emerald Central Hotel
# ceeldheer - nearest hotel: No hotel found
# farmville - nearest hotel: Hotel Weyanoke
# silifke - nearest hotel: Otel Arısan
# suva - nearest hotel: Extension 68
# chester - nearest hotel: Holiday Inn
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng","Lat", size = "Humidity", geo = True, tiles = "OSM", 
                                   hover_cols = ["Country","Hotel Name"])

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Country,Hotel Name)
